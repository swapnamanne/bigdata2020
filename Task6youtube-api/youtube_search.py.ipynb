# %%
from kafka import KafkaProducer
import json
import sys

# %%
api_key = "AIzaSyBRjKCR5KyxegZFCkNPQwl2yP6N2medSns"

# %%
producer = KafkaProducer(bootstrap_servers=['localhost:9093'],api_version=(0,10,1))

# %%
from apiclient.discovery import build

# %%
youtube = build('youtube', 'v3', developerKey=api_key)

# %%
type(youtube)
# Out:
# googleapiclient.discovery.Resource

# %%
req = youtube.search().list(q='princess', part='snippet', type='video', maxResults=50)

# %%
type(req)
# Out:
# googleapiclient.http.HttpRequest

# %%
res = req.execute()

# %%
for item in res['items']:
    print(item['snippet']['title'])
# Out:
# ADLEY iPAD TOUR!! playing Barbie Dream House, Princess Makeover, Toca Town pretend play, app reviews
# Alice and new Dresses for Princess - the best stories for kids
# Diana in her new princess room &amp; the magic suitcase for girls
# ちゃんみな [CHANMINA]    &quot;THE PRINCESS PROJECT - In The Screen&quot;
# Diana in her new princess room &amp; the magic suitcase
# Alice Dress Up For The Princess Ball - Cool DIY IDEAS how to makes a dress
# Sasha Sing-Along We are The Princess Song and play as Princesses | Nursery Rhymes and Kids Song
# Alice Dress Up as Rapunzel and plays with magical mirrors | best Princesses Stories
# Disney Princess GLOW UP
# DISNEY PRINCESS GENIES! (What Happens to Ariel, Elsa, Belle, Jasmine, Rapunzel and Anna?)
# Diana plays Hide and Seek with Disney Princess Dolls Video for kids
# Diana and Roma - Surprise for Cinderella Princess
# PRINCESS DATE NIGHT WITH ELSA AND ANNA, ARIEL, BELLE, RAPUNZEL, &amp; JASMINE. Totally TV Parody.
# ...

# %%
res['items']
# Out:
# [{'kind': 'youtube#searchResult',
#   'etag': 'hUM4lDlMOX3e-OUzhH-imDefs_0',
#   'id': {'kind': 'youtube#video', 'videoId': '-hS-SgbHvGY'},
#   'snippet': {'publishedAt': '2020-09-18T16:47:44Z',
#    'channelId': 'UCBJuxfqZuiibvcwSc8ViGsQ',
#    'title': 'ADLEY iPAD TOUR!! playing Barbie Dream House, Princess Makeover, Toca Town pretend play, app reviews',
#    'description': "Adley and Dad play our favorite games and more.. LET'S BE FRIENDS -- https://goo.gl/a7ctjJ HEY EVERYBODY!! Welcome back to my App Reviews!! Today I ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/-hS-SgbHvGY/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/-hS-SgbHvGY/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/-hS-SgbHvGY/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'A for Adley - Learning & Fun',
#    'liveBroadcastContent': 'none',
# ...

# %%
len(res['items'])
# Out:
# 50
